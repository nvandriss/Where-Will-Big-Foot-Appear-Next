# %%
import pandas as pd 
import os
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
sightings=pd.read_csv(os.path.join("cleaneddata", "sightings20_19.csv"))
homicide= pd.read_csv(os.path.join("cleaneddata", "Homicide.csv"))
missingpersons= pd.read_csv(os.path.join("cleaneddata", "Missing Persons JAS.csv"))
substance_use=pd.read_csv(os.path.join("cleaneddata", "NSDUH_Substance_Use_Data.csv"))
campgrounds=pd.read_csv(os.path.join("cleaneddata", "campgrounds.csv"))

# %%
sightings.head()
# Out:
#                                                title classification  year  \
# 0  Report 65679: Afternoon sighting of a bigfoot ...        Class A  2020
# 1  Report 67423: Sighting of a Sasquatch crossing...        Class A  2020
# 2  Report 63033: 1AM sighting of a Bigfoot on Hwy...        Class A  2019
# 3  Report 63153: Daylight sighting by hikers at M...        Class A  2019
# 4  Report 63731: Recent sighting on Connecticut W...        Class A  2019
#
#    latitude  longitude State        country
# 0  31.24305  -88.31126    AL  United States
# 1  33.64341  -85.41961    AL  United States
# 2  41.89288 -123.78790    CA  United States
# 3  39.41087 -106.14440    CO  United States
# 4  41.38622  -72.60558    CT  United States

# %%
sightingscount=sightings.groupby('State').count()
sightingscount
# Out:
#        title  classification  year  latitude  longitude  country
# State
# AL         2               2     2         2          2        2
# AR         3               3     3         3          3        3
# CA         5               5     5         5          5        5
# CO         3               3     3         3          3        3
# CT         2               2     2         2          2        2
# FL         2               2     2         2          2        2
# GA         1               1     1         1          1        1
# ID         6               6     6         6          6        6
# IL         1               1     1         1          1        1
# IN         2               2     2         2          2        2
# KY         1               1     1         1          1        1
# MA         1               1     1         1          1        1
# ME         3               3     3         3          3        3
# ...

# %%
sightingscount=sightingscount.reset_index()
hawaii={"State":'HI',
'title':0,}
DC={"State":'DC',
'title':0,}
AK={"State":'AK',
'title':0,}
AZ={"State":'AZ',
'title':0,}
DE={"State":'DE',
'title':0,}
IA={"State":'IA',
'title':0,}
KS={"State":'KS',
'title':0,}
LA={"State":'LA',
'title':0,}
MD={"State":'MD',
'title':0,}
MS={"State":'MS',
'title':0,}
ND={"State":'ND',
'title':0,}
NE={"State":'NE',
'title':0,}
NH={"State":'NH',
'title':0,}
NV={"State":'NV',
'title':0,}
RI={"State":'RI',
'title':0,}
UT={"State":'UT',
'title':0,}
VT={"State":'VT',
'title':0,}
WY={"State":'WY',
'title':0,}
sightingscount=sightingscount.drop(labels=['classification','year','latitude','longitude','country'],axis=1)
sightingscount.head()
sightingscount=sightingscount.append(DC,ignore_index=True)
sightingscount=sightingscount.append(hawaii,ignore_index=True)
sightingscount=sightingscount.append(AK,ignore_index=True)

sightingscount=sightingscount.append(AZ,ignore_index=True)

sightingscount=sightingscount.append(DE,ignore_index=True)

sightingscount=sightingscount.append(IA,ignore_index=True)

sightingscount=sightingscount.append(KS,ignore_index=True)

sightingscount=sightingscount.append(LA,ignore_index=True)

sightingscount=sightingscount.append(MD,ignore_index=True)

sightingscount=sightingscount.append(MS,ignore_index=True)

sightingscount=sightingscount.append(ND,ignore_index=True)

sightingscount=sightingscount.append(NE,ignore_index=True)

sightingscount=sightingscount.append(NH,ignore_index=True)

sightingscount=sightingscount.append(NV,ignore_index=True)

sightingscount=sightingscount.append(RI,ignore_index=True)

sightingscount=sightingscount.append(UT,ignore_index=True)

sightingscount=sightingscount.append(VT,ignore_index=True)

sightingscount=sightingscount.append(WY,ignore_index=True)

sightingscount=sightingscount.astype({'State':'string'})
sightingscount=sightingscount.astype({'title':'int64'})
sightingscount.dtypes
# Out:
# State    string
# title     int64
# dtype: object

# %%
homicide.dtypes
# Out:
# YEAR      float64
# STATE      object
# RATE      float64
# DEATHS     object
# URL        object
# dtype: object

# %%
homicide=homicide.drop(labels=['URL','DEATHS','YEAR'],axis=1)
homicide=homicide.dropna()
homicide=homicide.rename(columns={'STATE':'State'})
homicide=homicide.rename(columns={'RATE':'homicide_rate'})
homicide=homicide.astype({'State':'string'})
homicide=homicide.groupby('State').mean().reset_index()

# %%
DCh={"State":'DC',
'homicide_rate':23.5,}

# %%
homicide=homicide.reset_index()
homicide=homicide.append(DCh,ignore_index=True)
homicide=homicide.drop(labels='index',axis=1)
homicide
# Out:
#    State  homicide_rate
# 0     AK       7.728571
# 1     AL      11.085714
# 2     AR       8.585714
# 3     AZ       6.342857
# 4     CA       5.171429
# 5     CO       4.100000
# 6     CT       3.071429
# 7     DE       6.785714
# 8     FL       6.400000
# 9     GA       7.514286
# 10    HI       2.457143
# 11    IA       2.600000
# 12    ID       2.357143
# 13    IL       7.742857
# 14    IN       6.714286
# 15    KS       4.971429
# 16    KY       6.057143
# 17    LA      13.371429
# 18    MA       2.314286
# 19    MD       9.571429
# 20    ME       1.028571
# 21    MI       6.514286
# 22    MN       2.442857
# 23    MO       9.685714
# 24    MS      12.185714
# 25    MT       3.828571
# 26    NC       6.714286
# 27    ND       1.242857
# 28    NE       2.985714
# 29    NH       0.657143
# 30    NJ       4.257143
# 31    NM       9.028571
# 32    NV       7.000000
# 33    NY       3.500000
# 34    OH       6.314286
# 35    OK       7.728571
# 36    OR       2.942857
# ...

# %%
missingpersons.head()
# Out:
#         State  Total Number of Missing Persons  \
# 0     Alabama                              204
# 1      Alaska                              309
# 2     Arizona                              915
# 3    Arkansas                              200
# 4  California                             2133
#
#    Missing People per 100,000 Residents
# 0                                   4.2
# 1                                  41.8
# 2                                  13.0
# 3                                   6.7
# 4                                   5.4

# %%
missingpersons['State']=missingpersons['State'].map({
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC"
})
missingpersons
# Out:
#    State  Total Number of Missing Persons  \
# 0     AL                              204
# 1     AK                              309
# 2     AZ                              915
# 3     AR                              200
# 4     CA                             2133
# 5     CO                              292
# 6     CT                              197
# 7     DE                               58
# 8     DC                               35
# 9     FL                             1252
# 10    GA                              250
# 11    HI                              107
# 12    ID                              101
# 13    IL                              317
# 14    IN                              174
# 15    IA                               86
# 16    KS                               81
# 17    KY                              248
# 18    LA                              266
# 19    ME                              108
# 20    MD                              183
# ...

# %%
missingpersons.dtypes
missingpersons=missingpersons.astype({'State':'string'})
missingpersons.dtypes
# Out:
# State                                    string
# Total Number of Missing Persons           int64
# Missing People per 100,000 Residents    float64
# dtype: object

# %%
substance_use.head(10)
# Out:
#    Unnamed: 0       State Illicit Drug Use (18+) Alcohol Use (18+)  \
# 0           0  Total U.S.                  6.82%            10.96%
# 1           1   Northeast                  6.75%            11.59%
# 2           2     Midwest                  6.87%            11.48%
# 3           3       South                  6.46%             9.38%
# 4           4        West                  7.41%            12.57%
# 5           5     Alabama                  5.63%             9.31%
# 6           6      Alaska                  7.87%            11.30%
# 7           7     Arizona                  7.76%            11.85%
# 8           8    Arkansas                  7.75%             9.12%
# 9           9  California                  6.72%            12.79%
#
#   Substance Use Disorder (18+)
# 0                       10.96%
# 1                       11.59%
# 2                       11.48%
# 3                        9.38%
# 4                       12.57%
# 5                        9.31%
# ...

# %%
substance_use=substance_use.drop(substance_use.index[[0,1,2,3,4]])

substance_use.dtypes

substance_use.dtypes
substance_use['State']=substance_use['State'].map({
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC"
})
substance_use=substance_use.drop(labels='Unnamed: 0',axis=1)
substance_use=substance_use.astype({'State':'string'})

# %%
substance_use['Illicit Drug Use (18+)']=substance_use['Illicit Drug Use (18+)'].str.rstrip('%')
substance_use['Alcohol Use (18+)']=substance_use['Alcohol Use (18+)'].str.rstrip('%')
substance_use['Substance Use Disorder (18+)']=substance_use['Substance Use Disorder (18+)'].str.rstrip('%')
substance_use=substance_use.astype({'Illicit Drug Use (18+)':'float'})
substance_use=substance_use.astype({'Alcohol Use (18+)':'float'})
substance_use=substance_use.astype({'Substance Use Disorder (18+)':'float'})
substance_use.dtypes
# Out:
# State                            string
# Illicit Drug Use (18+)          float64
# Alcohol Use (18+)               float64
# Substance Use Disorder (18+)    float64
# dtype: object

# %%
substance_use
# Out:
#    State  Illicit Drug Use (18+)  Alcohol Use (18+)  \
# 5     AL                    5.63               9.31
# 6     AK                    7.87              11.30
# 7     AZ                    7.76              11.85
# 8     AR                    7.75               9.12
# 9     CA                    6.72              12.79
# 10    CO                    9.01              13.32
# 11    CT                    6.70              12.21
# 12    DE                    5.79              10.82
# 13    DC                    9.70              17.83
# 14    FL                    7.48               9.55
# 15    GA                    5.33               8.03
# 16    HI                    5.85              10.31
# 17    ID                    6.92              10.87
# 18    IL                    7.65              11.51
# 19    IN                    6.73              10.05
# 20    IA                    6.67              10.55
# 21    KS                    7.00              13.48
# ...

# %%
campgroundscount=campgrounds.groupby('State').count().reset_index()
campgroundscount=campgroundscount.drop(labels=['Unnamed: 0','Long','Lat','Code','Type','City'],axis=1)
DCc={"State":'DC',
'Campground':0}
campgroundscount=campgroundscount.append(DCc,ignore_index=True)

# %%
campgroundscount
# Out:
#    State  Campground
# 0     AK         100
# 1     AL         116
# 2     AR         241
# 3     AZ         259
# 4     CA        1301
# 5     CO         507
# 6     CT          18
# 7     DE           7
# 8     FL         180
# 9     GA         179
# 10    HI          36
# 11    IA         497
# 12    ID         497
# 13    IL         163
# 14    IN         111
# 15    KS         214
# 16    KY         136
# 17    LA          88
# 18    MA          36
# 19    MD          46
# 20    ME          32
# 21    MI         488
# 22    MN         392
# 23    MO         189
# 24    MS         137
# 25    MT         481
# 26    NC         105
# 27    ND         249
# 28    NE         263
# 29    NH          44
# 30    NJ          26
# 31    NM         212
# 32    NV          98
# 33    NY         149
# 34    OH         114
# 35    OK         251
# 36    OR         720
# 37    PA         112
# 38    RI           9
# 39    SC          71
# 40    SD         178
# 41    TN         135
# ...

# %%
alldata_df=pd.merge(sightingscount,campgroundscount,how='right', on='State')
alldata_df=pd.merge(alldata_df,substance_use,how='left', on='State')
alldata_df=pd.merge(alldata_df,missingpersons,how='left', on='State')
alldata_df=pd.merge(alldata_df,homicide,how='left', on='State')
alldata_df=alldata_df.rename(columns={'title':'count_sightings'})
#alldata_df=alldata_df.astype({'State':'string'})
alldata_df
# Out:
#    State  count_sightings  Campground  Illicit Drug Use (18+)  \
# 0     AK                0         100                    7.87
# 1     AL                2         116                    5.63
# 2     AR                3         241                    7.75
# 3     AZ                0         259                    7.76
# 4     CA                5        1301                    6.72
# 5     CO                3         507                    9.01
# 6     CT                2          18                    6.70
# 7     DE                0           7                    5.79
# 8     FL                2         180                    7.48
# 9     GA                1         179                    5.33
# 10    HI                0          36                    5.85
# 11    IA                0         497                    6.67
# 12    ID                6         497                    6.92
# 13    IL                1         163                    7.65
# ...

# %%
alldata_df=alldata_df[['State','Campground','Illicit Drug Use (18+)','Alcohol Use (18+)','Substance Use Disorder (18+)','Missing People per 100,000 Residents','homicide_rate','count_sightings']]
alldata_dummies_df=pd.get_dummies(alldata_df)
alldata_df=alldata_dummies_df[['Illicit Drug Use (18+)', 'Alcohol Use (18+)',
       'Substance Use Disorder (18+)', 'Missing People per 100,000 Residents',
       'Campground' ,'State_AK', 'State_AL', 'State_AR',
       'State_AZ', 'State_CA', 'State_CO', 'State_CT', 'State_DC', 'State_DE',
       'State_FL', 'State_GA', 'State_HI', 'State_IA', 'State_ID', 'State_IL',
       'State_IN', 'State_KS', 'State_KY', 'State_LA', 'State_MA', 'State_MD',
       'State_ME', 'State_MI', 'State_MN', 'State_MO', 'State_MS', 'State_MT',
       'State_NC', 'State_ND', 'State_NE', 'State_NH', 'State_NJ', 'State_NM',
       'State_NV', 'State_NY', 'State_OH', 'State_OK', 'State_OR', 'State_PA',
       'State_RI', 'State_SC', 'State_SD', 'State_TN', 'State_TX', 'State_UT',
       'State_VA', 'State_VT', 'State_WA', 'State_WI', 'State_WV', 'State_WY','count_sightings']]
alldata_df.dtypes
# Out:
# Illicit Drug Use (18+)                  float64
# Alcohol Use (18+)                       float64
# Substance Use Disorder (18+)            float64
# Missing People per 100,000 Residents    float64
# Campground                                int64
# State_AK                                  uint8
# State_AL                                  uint8
# State_AR                                  uint8
# State_AZ                                  uint8
# State_CA                                  uint8
# State_CO                                  uint8
# State_CT                                  uint8
# State_DC                                  uint8
# State_DE                                  uint8
# State_FL                                  uint8
# State_GA                                  uint8
# State_HI                                  uint8
# State_IA                                  uint8
# State_ID                                  uint8
# State_IL                                  uint8
# ...

# %% [markdown]
# Regression

# %%
X=alldata_df.iloc[:, :-1].values
y=alldata_df.iloc[:, -1].values
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (51, 56) (51,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model = LinearRegression()

# %%
bfmodel=model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 1.0
# Testing Score: 0.08572922628741086

# %%
bfmodel.coef_
# Out:
# array([-3.18899248e-01, -5.59770575e-02, -5.59770575e-02, -2.61337436e-02,
#         2.85402023e-03, -2.71508116e-01, -2.36924203e-01,  1.12645275e+00,
#         2.44249065e-15,  1.49622813e-01,  1.20010309e+00,  7.42632776e-01,
#         3.66818140e-01, -1.65872067e+00, -2.22044605e-16, -1.70273926e+00,
#        -1.74024928e+00, -2.89302821e+00, -4.44089210e-16,  1.11022302e-15,
#         1.69167126e-01, -1.64946480e+00, -1.19272160e+00,  2.22044605e-16,
#         6.47384990e-02, -1.40692268e+00,  1.93787664e+00, -1.31853150e+00,
#        -4.90386424e-01,  3.13999165e+00, -4.44089210e-16, -8.19597986e-02,
#         2.08886396e+00, -2.04205003e+00, -1.90265246e+00, -1.21642720e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.12019143e+00,
#         9.07142078e+00,  3.13844904e-01,  7.58964385e-01, -8.05048201e-01,
#        -7.91368713e-01, -1.02717956e+00,  0.00000000e+00, -8.44339038e-01,
# ...

# %%
from sklearn.decomposition import PCA

# %%
steps = [
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=0.9)),
    ('lr', LinearRegression())
]

# %%
from sklearn.pipeline import Pipeline
pipe = Pipeline(steps)

# %%
params = {'lr__normalize': [True, False], 
         }

# %%
from sklearn.model_selection import GridSearchCV
cv = GridSearchCV(pipe,params)
cv.fit(X_train, y_train)
cv.score(X_test, y_test)
# Out:
# 0.02574546261495425
