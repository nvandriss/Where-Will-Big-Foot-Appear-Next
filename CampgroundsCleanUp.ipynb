# %%
import pandas as pd
import numpy as np

# %%
midwestpath='Resources/MidwestCamp.csv'
northeastpath='Resources/NortheastCamp.csv'
southpath='Resources/SouthCamp.csv'
southwestpath='Resources/SouthwestCamp.csv'
westpath='Resources/WestCamp.csv'

# %%
midwest_df=pd.read_csv(midwestpath, engine='python')
northeast_df=pd.read_csv(northeastpath, engine='python')
south_df=pd.read_csv(southpath, engine='python')
southwest_df=pd.read_csv(southwestpath, engine='python')
west_df=pd.read_csv(westpath, engine='python')

# %%
midwest_df
# Out:
#       Unnamed: 0    Long     Lat  Code                       Campground Type  \
# 0            NaN  42.953 -92.875  ACKL         Ackley Creek County Park   CP
# 1            NaN  41.738 -93.724  ACOR  Acorn Valley - Saylorville Lake  COE
# 2            NaN  41.498 -94.643  ADAI                  Adair City Park   CP
# 3            NaN  43.120 -92.210  ADOL               Adolph Munson Park   CP
# 4            NaN  43.090 -92.348  AIRP                Airport Lake Park   CP
# ...          ...     ...     ...   ...                              ...  ...
# 3162         NaN  45.014 -92.691  WILL          Willow River State Park   SP
# 3163         NaN  45.930 -88.861  WIND                      Windsor Dam   NF
# 3164         NaN  43.659 -90.220  WONE              Wonewoc Legion Park   CP
# 3165         NaN  42.994 -91.116  WYAL             Wyalusing State Park   SP
# 3166         NaN  42.769 -89.971  YELL      Yellowstone Lake State Park   SP
#
#                 City State
# 0        Marble Rock    IA
# 1         Des Moines    IA
# 2              Adair    IA
# 3        New Hampton    IA
# 4        New Hampton    IA
# ...              ...   ...
# 3162          Hudson    WI
# 3163     Eagle River    WI
# 3164         Wonewon    WI
# 3165          Bagley    WI
# 3166  Blanchardville    WI
#
# [3167 rows x 8 columns]

# %%
northeast_df
# Out:
#      Unnamed: 0    Long     Lat  Code  \
# 0           NaN  41.651 -73.098  BLAC
# 1           NaN  41.484 -72.342  DEVI
# 2           NaN  41.534 -71.811  GREE
# 3           NaN  41.265 -72.556  HAMM
# 4           NaN  41.935 -73.004  HAWS
# ..          ...     ...     ...   ...
# 713         NaN  37.622 -81.428  TWIN
# 714         NaN  39.308 -79.994  TYGA
# 715         NaN  37.846 -80.975  WARR
# 716         NaN  38.007 -80.012  WEST
# 717         NaN  38.925 -78.689  WOLF
#
#                                        Campground Type           City State
# 0                           Black Rock State Park   SP      Thomaston    CT
# 1                       Devils Hopyard State Park   SP    East Haddam    CT
# 2              Green Falls - Pachaug State Forest   SF            NaN    CT
# 3                          Hammonasset State Park   SP        Madison    CT
# 4    Haws Memorial - American Legion State Forest   SF    Barkhamsted    CT
# ..                                            ...  ...            ...   ...
# 713                  Twin Falls Resort State Park   SP        Mullens    WV
# 714                        Tygart Lake State Park   SP        Grafton    WV
# 715   War Ridge - New River National Scenic River   NP  Meadow Bridge    WV
# 716                    West Shore - Lake Sherwood   NF        Eastern    WV
# 717                                      Wolf Gap   NF   Wardensville    WV
#
# [718 rows x 8 columns]

# %%
south_df
# Out:
#       Unnamed: 0    Long      Lat  Code                         Campground  \
# 0            NaN  32.977  -85.214  AMIT                              Amity
# 1            NaN  33.621  -85.963  ANNI    Anniston Army Depot RV Military
# 2            NaN  34.427  -87.924  BEA3                   Bear Creek Lakes
# 3            NaN  34.448  -87.966  BEA2                   Bear Creek Lakes
# 4            NaN  31.806  -87.422  BELL                      Bells Landing
# ...          ...     ...      ...   ...                                ...
# 2120         NaN  30.665  -95.151  WOLP  Wolf Creek Park - Lake Livingston
# 2121         NaN  36.227 -100.646  WOLC         Wolf Creek Park - Perryton
# 2122         NaN  30.295  -96.535  YEGU      Yegua Creek - Lake Somerville
# 2123         NaN  29.305  -97.129  YOAK                   Yoakum City Park
# 2124         NaN  33.049 -102.818  YOAK                 Yoakum County Park
#
#       Type          City State
# 0      COE        Lanett    AL
# 1      MIL      Anniston    AL
# 2     AUTH  Russellville    AL
# 3     AUTH        Hodges    AL
# 4      COE        Camden    AL
# ...    ...           ...   ...
# 2120  AUTH           NaN    TX
# 2121    CP      Perryton    TX
# 2122   COE    Somerville    TX
# 2123    CP        Yoakum    TX
# 2124    CP   Denver City    TX
#
# [2125 rows x 8 columns]

# %%
southwest_df
# Out:
#       Unnamed: 0    Long      Lat  Code  \
# 0            NaN  32.180 -110.861  AGAV
# 1            NaN  34.231 -113.579  ALAM
# 2            NaN  33.895 -109.153  ALPI
# 3            NaN  34.589 -112.561  ALTO
# 4            NaN  31.560 -110.366  APAF
# ...          ...     ...      ...   ...
# 1467         NaN  41.797 -111.644  WOOD
# 1468         NaN  40.536 -110.637  YEP1
# 1469         NaN  40.631 -111.173  YEP2
# 1470         NaN  40.542 -110.337  YELL
# 1471         NaN  40.546 -110.333  YELB
#
#                                   Campground Type           City State
# 0                       Agave Gulch Military  MIL            NaN    AZ
# 1                      Alamo Lake State Park   SP         Wenden    AZ
# 2                              Alpine Divide   NF         Alpine    AZ
# 3                                   Alto Pit   NF       Prescott    AZ
# 4     Apache Flats Military -  Fort Huachuca  MIL   Sierra Vista    AZ
# ...                                      ...  ...            ...   ...
# 1467                               Wood Camp   NF          Logan    UT
# 1468                             Yellow Pine   NF  Mountain Home    UT
# 1469                             Yellow Pine   NF          Kamas    UT
# 1470                             Yellowstone   NF  Mountain Home    UT
# 1471                      Yellowstone Bridge   NF        Altonah    UT
#
# [1472 rows x 8 columns]

# %%
west_df
# Out:
#       Unnamed: 0    Long      Lat  Code  \
# 0            NaN  61.086 -146.343  ALLI
# 1            NaN  59.768 -151.865  ANCH
# 2            NaN  66.566 -150.810  ARCT
# 3            NaN  58.381 -134.737  AUKV
# 4            NaN  60.751 -149.256  BERT
# ...          ...     ...      ...   ...
# 3921         NaN  43.196 -110.885  WOLF
# 3922         NaN  43.932 -109.132  WOOD
# 3923         NaN  41.504 -111.020  WOOD
# 3924         NaN  42.699 -108.930  WORT
# 3925         NaN  41.255 -105.411  YELL
#
#                                     Campground Type          City State
# 0                                Allison Point   CP        Valdez    AK
# 1                  Anchor River State Rec Area  SRA  Anchor Point    AK
# 2                   Arctic Circle - Dalton Hwy  BLM           NaN    AK
# 3                                  Auk Village   NF        Juneau    AK
# 4                                 Bertha Creek   NF          Hope    AK
# ...                                        ...  ...           ...   ...
# 3921                                Wolf Creek   NF       Jackson    WY
# 3922                                Wood River   NF           NaN    WY
# 3923  Woodruff Narrows/Bear River Access - WGF  SFW      Evanston    WY
# 3924                           Worthen Meadows   NF        Lander    WY
# 3925                               Yellow Pine   NF       Laramie    WY
#
# [3926 rows x 8 columns]

# %%
campgrounds_df = midwest_df.append(northeast_df)
campgrounds_df = campgrounds_df.append(south_df)
campgrounds_df = campgrounds_df.append(southwest_df)
campgrounds_df = campgrounds_df.append(west_df)
campgrounds_df
# Out:
#       Unnamed: 0    Long      Lat  Code  \
# 0            NaN  42.953  -92.875  ACKL
# 1            NaN  41.738  -93.724  ACOR
# 2            NaN  41.498  -94.643  ADAI
# 3            NaN  43.120  -92.210  ADOL
# 4            NaN  43.090  -92.348  AIRP
# ...          ...     ...      ...   ...
# 3921         NaN  43.196 -110.885  WOLF
# 3922         NaN  43.932 -109.132  WOOD
# 3923         NaN  41.504 -111.020  WOOD
# 3924         NaN  42.699 -108.930  WORT
# 3925         NaN  41.255 -105.411  YELL
#
#                                     Campground Type         City State
# 0                     Ackley Creek County Park   CP  Marble Rock    IA
# 1              Acorn Valley - Saylorville Lake  COE   Des Moines    IA
# 2                              Adair City Park   CP        Adair    IA
# 3                           Adolph Munson Park   CP  New Hampton    IA
# 4                            Airport Lake Park   CP  New Hampton    IA
# ...                                        ...  ...          ...   ...
# 3921                                Wolf Creek   NF      Jackson    WY
# 3922                                Wood River   NF          NaN    WY
# 3923  Woodruff Narrows/Bear River Access - WGF  SFW     Evanston    WY
# 3924                           Worthen Meadows   NF       Lander    WY
# 3925                               Yellow Pine   NF      Laramie    WY
#
# [11408 rows x 8 columns]

# %%
campgrounds_df.dropna()

campgrounds_df = campgrounds_df[['Lat', 
                            'Long', 
                            'Code', 
                            'Campground', 
                            'Type', 
                            'City', 
                            'State']]
campgrounds_df
# Out:
#         Long      Lat  Code                                Campground Type  \
# 0     42.953  -92.875  ACKL                  Ackley Creek County Park   CP
# 1     41.738  -93.724  ACOR           Acorn Valley - Saylorville Lake  COE
# 2     41.498  -94.643  ADAI                           Adair City Park   CP
# 3     43.120  -92.210  ADOL                        Adolph Munson Park   CP
# 4     43.090  -92.348  AIRP                         Airport Lake Park   CP
# ...      ...      ...   ...                                       ...  ...
# 3921  43.196 -110.885  WOLF                                Wolf Creek   NF
# 3922  43.932 -109.132  WOOD                                Wood River   NF
# 3923  41.504 -111.020  WOOD  Woodruff Narrows/Bear River Access - WGF  SFW
# 3924  42.699 -108.930  WORT                           Worthen Meadows   NF
# 3925  41.255 -105.411  YELL                               Yellow Pine   NF
#
#              City State
# 0     Marble Rock    IA
# 1      Des Moines    IA
# 2           Adair    IA
# 3     New Hampton    IA
# 4     New Hampton    IA
# ...           ...   ...
# 3921      Jackson    WY
# 3922          NaN    WY
# 3923     Evanston    WY
# 3924       Lander    WY
# 3925      Laramie    WY
#
# [11408 rows x 7 columns]

# %%
campgrounds = campgrounds_df.sort_values('State')
campgrounds.head()
# Out:
#       Long      Lat  Code                Campground Type        City State
# 91  60.416 -149.381  TRAI               Trail River   NF  Moose Pass    AK
# 67  62.868 -145.535  PAXS               Paxson Lake  BLM      Gakona    AK
# 66  65.370 -147.088  OPHI  Ophir Creek - Steese Hwy  BLM         NaN    AK
# 65  56.580 -132.741  OHME               Ohmer Creek   NF  Petersburg    AK
# 64  60.051 -151.668  NINI  Ninilchik State Rec Area  SRA   Ninilchik    AK

# %%
campgrounds.to_csv('campgrounds.csv')
