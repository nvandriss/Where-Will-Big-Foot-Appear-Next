# %%
import pandas as pd
import numpy as np

#import census data
pop_change_df = pd.read_csv('Resources/population-change-data-table-usable.csv')
pop_change_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          59 non-null     object
#  1   Resident Population 2020 Census     57 non-null     object
#  2   Percent Change 2010 to 2020 Census  57 non-null     float64
#  3   Resident Population 2010 Census     57 non-null     object
#  4   Percent Change 2000 - Census 2010   57 non-null     float64
#  5   Resident Population 2000 Census     57 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 2.9+ KB

# %%
#change "Unamed to "State"
pop_change_df1 = pop_change_df.rename(columns = {"Unnamed: 0": "State"})

# %%
#drop regional and national totals
pop_change_df2 = pop_change_df1.drop(labels= range(51,59), axis=0)
pop_change_df2
# Out:
#                    State Resident Population 2020 Census  \
# 0                Alabama                       5,024,279
# 1                 Alaska                         733,391
# 2                Arizona                       7,151,502
# 3               Arkansas                       3,011,524
# 4             California                      39,538,223
# 5               Colorado                       5,773,714
# 6            Connecticut                       3,605,944
# 7               Delaware                         989,948
# 8   District of Columbia                         689,545
# 9                Florida                      21,538,187
# 10               Georgia                      10,711,908
# 11                Hawaii                       1,455,271
# 12                 Idaho                       1,839,106
# 13              Illinois                      12,812,508
# 14               Indiana                       6,785,528
# ...

# %%
#import substance abuse data
subs_df = pd.read_csv("Resources/NSDUH Substance Use Data JAS.csv")
subs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    56 non-null     int64
#  1   State                         56 non-null     object
#  2   Illicit Drug Use (18+)        56 non-null     float64
#  3   Alcohol Use (18+)             56 non-null     float64
#  4   Substance Use Disorder (18+)  56 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 2.3+ KB

# %%
#drop regional data
subs_df1 = subs_df.drop(labels= range(0,5), axis=0)
subs_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 5 to 55
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    51 non-null     int64
#  1   State                         51 non-null     object
#  2   Illicit Drug Use (18+)        51 non-null     float64
#  3   Alcohol Use (18+)             51 non-null     float64
#  4   Substance Use Disorder (18+)  51 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 2.4+ KB

# %%
subs_df2 = subs_df.set_index('State')
subs_df2
# Out:
#                       Unnamed: 0  Illicit Drug Use (18+)  Alcohol Use (18+)  \
# State
# Total U.S.                     0                    0.07               0.11
# Northeast                      1                    0.07               0.12
# Midwest                        2                    0.07               0.11
# South                          3                    0.06               0.09
# West                           4                    0.07               0.13
# Alabama                        5                    0.06               0.09
# Alaska                         6                    0.08               0.11
# Arizona                        7                    0.08               0.12
# Arkansas                       8                    0.08               0.09
# California                     9                    0.07               0.13
# Colorado                      10                    0.09               0.13
# ...

# %%
#import missing persons data
missing_df = pd.read_csv("Missing Persons JAS.csv")
                        
missing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   State                                 51 non-null     object
#  1   Total Number of Missing Persons       51 non-null     int64
#  2   Missing People per 100,000 Residents  51 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ KB

# %%
sightings_df = pd.read_csv("sightings_df.csv")
sightings_df
# Out:
#       Unnamed: 0                                              title  \
# 0              0  Report 637: Campers' encounter just after dark...
# 1              1  Report 2917: Family observes large biped from car
# 2              2  Report 7963: Sasquatch walks past window of ho...
# 3              3  Report 9317: Driver on Alcan Highway has noon,...
# 4              5  Report 23666: Passenger on the Alcan Highway s...
# ...          ...                                                ...
# 4052        4245  Report 4159: Campers hear unusual grunting sou...
# 4053        4246  Report 175: Campers encounter large animal nea...
# 4054        4247    Report 945: Creature with red glowing eyes seen
# 4055        4248  Report 1387: Father and son hear heavy footste...
# 4056        4249  Report 3044: Second-hand report of creature lo...
#
#      classification  year  latitude  longitude State        country
# 0           Class A  2000  61.50000 -142.90000    AK  United States
# ...

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}
    
# invert the dictionary
abbrev_to_us_state = dict(map(reversed, us_state_to_abbrev.items()))

# %%
sightings_df['State']=sightings_df['State'].map(abbrev_to_us_state)

# %%
#sort sightings by year
sightings_df1 = sightings_df.sort_values(by="year")

sightings_df1.head()
# Out:
#       Unnamed: 0                                              title  \
# 211          213  Report 14338: Old newspaper article (Titusvill...
# 1453        1525  Report 14358: Old newspaper article (Clearfiel...
# 2777        2963  Report 24413: Woman recounts a tale her Grandf...
# 3489        3680  Report 2477: Nine foot tall brown/black creatu...
# 2951        3139  Report 24102: Recollections of numerous encoun...
#
#      classification  year  latitude     longitude         State        country
# 211         Class A  1869  37.39555 -1.214871e+02    California  United States
# 1453        Class A  1921  41.01865 -7.837700e+01  Pennsylvania  United States
# 2777        Class B  1925  31.08774 -9.184467e+01     Louisiana  United States
# 3489        Class B  1930  31.40444 -9.570861e+01         Texas  United States
# 2951        Class B  1932  39.80751 -9.486840e+07        Nevada  United States

# %%
#drop the sightings from before 2001
sightings_df2 = sightings_df1[sightings_df1['year']>2000]
sightings_df2
# Out:
#       Unnamed: 0                                              title  \
# 3492        3683  Report 3587: Late afternoon sighting at creek,...
# 2020        2094  Report 8797: Two boys find footprints on Harri...
# 3575        3766  Report 18056: Possible late night sighting by ...
# 1315        1387  Report 2041: August 1 1990 Oklahoma, Cherokee ...
# 1966        2038  Report 3655: Daylight sighting near rural chur...
# ...          ...                                                ...
# 3942        4134  Report 70737: Heavy thuds and distinct rock cl...
# 3941        4133  Report 69553: Possible encounter in darkness o...
# 3272        3462  Report 71751: Possible sighting in Mohican Sta...
# 689          760  Report 71920: SATURDAY NIGHT 10:30 : Motorist ...
# 3088        3277  Report 45647: Memory told of a possible encoun...
#
#      classification  year  latitude  longitude          State        country
# ...

# %%
#create a dataframe for 2001 to 2010
sightings_00s = sightings_df2[sightings_df['year']<2011]
sightings_00s
# Out:
# C:\Users\jenny\AppData\Local\Temp/ipykernel_19128/366629599.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sightings_00s = sightings_df2[sightings_df['year']<2011]
#       Unnamed: 0                                              title  \
# 3492        3683  Report 3587: Late afternoon sighting at creek,...
# 2020        2094  Report 8797: Two boys find footprints on Harri...
# 3575        3766  Report 18056: Possible late night sighting by ...
# 1315        1387  Report 2041: August 1 1990 Oklahoma, Cherokee ...
# 1966        2038  Report 3655: Daylight sighting near rural chur...
# ...          ...                                                ...
# 2644        2830  Report 33040: Possible sighting by a deer hunt...
# 2552        2738  Report 35883: Possible encounter while volunte...
# 653          724  Report 37856: Close encounter at night by a mo...
# 236          238  Report 27177: Man remembers sighting while dri...
# ...

# %%
#get the count for 2001-2010 by state
sightings_00s_state = sightings_00s.groupby('State').count()

sightings_00s_state.head()
# Out:
#             Unnamed: 0  title  classification  year  latitude  longitude  \
# State
# Alabama             36     36              36    36        36         36
# Alaska               7      7               7     7         7          7
# Arizona             34     34              34    34        34         34
# Arkansas            42     42              42    42        42         42
# California         123    123             123   123       123        123
#
#             country
# State
# Alabama          36
# Alaska            7
# Arizona          34
# Arkansas         42
# California      123

# %%
bf_sitings_00s = sightings_00s_state.rename(columns= {"Unnamed": "10 Count"})

# %%
#create dataframe for 2011-2020
sightings_10s = sightings_df2[sightings_df['year']>=2001]
sightings_10s
# Out:
# C:\Users\jenny\AppData\Local\Temp/ipykernel_19128/3474300916.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sightings_10s = sightings_df2[sightings_df['year']>=2001]
#       Unnamed: 0                                              title  \
# 3492        3683  Report 3587: Late afternoon sighting at creek,...
# 2020        2094  Report 8797: Two boys find footprints on Harri...
# 3575        3766  Report 18056: Possible late night sighting by ...
# 1315        1387  Report 2041: August 1 1990 Oklahoma, Cherokee ...
# 1966        2038  Report 3655: Daylight sighting near rural chur...
# ...          ...                                                ...
# 3942        4134  Report 70737: Heavy thuds and distinct rock cl...
# 3941        4133  Report 69553: Possible encounter in darkness o...
# 3272        3462  Report 71751: Possible sighting in Mohican Sta...
# 689          760  Report 71920: SATURDAY NIGHT 10:30 : Motorist ...
# ...

# %%
#get counts of sightings for 2011-2020
sightings_10s_state = sightings_10s.groupby('State').count()
sightings_10s_state
# Out:
#                 Unnamed: 0  title  classification  year  latitude  longitude  \
# State
# Alabama                 59     59              59    59        59         59
# Alaska                   7      7               7     7         7          7
# Arizona                 46     46              46    46        46         46
# Arkansas                61     61              61    61        61         61
# California             142    142             142   142       142        142
# Colorado                56     56              56    56        56         56
# Connecticut             11     11              11    11        11         11
# Delaware                 2      2               2     2         2          2
# Florida                167    167             167   167       167        167
# Georgia                 71     71              71    71        71         71
# Idaho                   46     46              46    46        46         46
# ...

# %%
#Merge dataframes
aggregate_df= pd.merge(pop_change_df2, missing_df, on='State', how='left')
aggregate_df.head()
# Out:
#         State Resident Population 2020 Census  \
# 0     Alabama                       5,024,279
# 1      Alaska                         733,391
# 2     Arizona                       7,151,502
# 3    Arkansas                       3,011,524
# 4  California                      39,538,223
#
#    Percent Change 2010 to 2020 Census Resident Population 2010 Census  \
# 0                                 5.1                       4,779,736
# 1                                 3.3                         710,231
# 2                                11.9                       6,392,017
# 3                                 3.3                       2,915,918
# 4                                 6.1                      37,253,956
#
#    Percent Change 2000 - Census 2010 Resident Population 2000 Census  \
# 0                                7.5                       4,447,100
# 1                               13.3                         626,932
# ...

# %%
sittings_aggregate_00_df = pd.merge(aggregate_df,sightings_00s_state, on='State', how='left')
sittings_aggregate_00_df.head()
# Out:
#         State Resident Population 2020 Census  \
# 0     Alabama                       5,024,279
# 1      Alaska                         733,391
# 2     Arizona                       7,151,502
# 3    Arkansas                       3,011,524
# 4  California                      39,538,223
#
#    Percent Change 2010 to 2020 Census Resident Population 2010 Census  \
# 0                                 5.1                       4,779,736
# 1                                 3.3                         710,231
# 2                                11.9                       6,392,017
# 3                                 3.3                       2,915,918
# 4                                 6.1                      37,253,956
#
#    Percent Change 2000 - Census 2010 Resident Population 2000 Census  \
# 0                                7.5                       4,447,100
# 1                               13.3                         626,932
# ...

# %%
ag_00s_rename = sittings_aggregate_00_df.rename(columns = {"State": "State", 
                                                           "Resident Population 2020 Census": "2020 Pop",
                                                           "Percent Change 2020 Census": "2020 % Change",
                                                           "Resident Population 2010 Census": "2010 Pop",
                                                           "Percent Change 2010 Census": "2010 % Change",
                                                           "Resident Population 2000 Census": "2000 Pop",
                                                           "Total Number of Missing Persons": " # Missing",
                                                           "Missing People 100,000 Residents": "Missing Per 100k",
                                                           "Unnamed":"2001-2010 Sightings", 
                                                           "latitude":"Lat Count",
                                                           "latitude.1": "Lat1 Count",
                                                           "classification": "Class Count",
                                                           "title": "Title Count",
                                                           "Date": "Date Count",
                                                           "Year": "2001-2010 Count"
                                                            })

# %%
agg_total=pd.merge(ag_00s_rename, sightings_10s_state, on='State', how='left' )
agg_total.head()
# Out:
#         State    2020 Pop  Percent Change 2010 to 2020 Census    2010 Pop  \
# 0     Alabama   5,024,279                                 5.1   4,779,736
# 1      Alaska     733,391                                 3.3     710,231
# 2     Arizona   7,151,502                                11.9   6,392,017
# 3    Arkansas   3,011,524                                 3.3   2,915,918
# 4  California  39,538,223                                 6.1  37,253,956
#
#    Percent Change 2000 - Census 2010    2000 Pop   # Missing  \
# 0                                7.5   4,447,100         204
# 1                               13.3     626,932         309
# 2                               24.6   5,130,632         915
# 3                                9.1   2,673,400         200
# 4                               10.0  33,871,648        2133
#
#    Missing People per 100,000 Residents  Unnamed: 0_x  Title Count  ...  \
# 0                                   4.2          36.0         36.0  ...
# ...

# %%
agg_df2=agg_total.rename(columns = {
                                     "latitude": "20 Lat",
                                     "latitude.1": "20 Lat 1", 
                                     "classification": "20 Class", 
                                     "title": "20 Title", 
                                     "Date": "20 Date", 
                                     "Year": "20 year",
                                      })

# %%
agg_df2.set_index('State')
agg_df2.head()
# Out:
#         State    2020 Pop  Percent Change 2010 to 2020 Census    2010 Pop  \
# 0     Alabama   5,024,279                                 5.1   4,779,736
# 1      Alaska     733,391                                 3.3     710,231
# 2     Arizona   7,151,502                                11.9   6,392,017
# 3    Arkansas   3,011,524                                 3.3   2,915,918
# 4  California  39,538,223                                 6.1  37,253,956
#
#    Percent Change 2000 - Census 2010    2000 Pop   # Missing  \
# 0                                7.5   4,447,100         204
# 1                               13.3     626,932         309
# 2                               24.6   5,130,632         915
# 3                                9.1   2,673,400         200
# 4                               10.0  33,871,648        2133
#
#    Missing People per 100,000 Residents  Unnamed: 0_x  Title Count  ...  \
# 0                                   4.2          36.0         36.0  ...
# ...

# %%
final_df = pd.merge(agg_df2, subs_df2, on="State", how="left")

# %%
#Change NaN values to zero
bf_final = final_df.fillna(0)
bf_final_state = bf_final.set_index('State')
bf_final_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, Alabama to Wyoming
# Data columns (total 25 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   2020 Pop                              51 non-null     object
#  1   Percent Change 2010 to 2020 Census    51 non-null     float64
#  2   2010 Pop                              51 non-null     object
#  3   Percent Change 2000 - Census 2010     51 non-null     float64
#  4   2000 Pop                              51 non-null     object
#  5    # Missing                            51 non-null     int64
#  6   Missing People per 100,000 Residents  51 non-null     float64
#  7   Unnamed: 0_x                          51 non-null     float64
#  8   Title Count                           51 non-null     float64
#  9   Class Count                           51 non-null     float64
# ...

# %%
#find states with greatest increase in Bigfoot sightings
bf_increase = (bf_final_state["20 Class"] - bf_final_state["Title Count"])
bf_increase
# Out:
# State
# Alabama                  23.0
# Alaska                    0.0
# Arizona                  12.0
# Arkansas                 19.0
# California               19.0
# Colorado                 16.0
# Connecticut               9.0
# Delaware                  1.0
# District of Columbia      0.0
# Florida                  70.0
# Georgia                  22.0
# Hawaii                    0.0
# Idaho                    24.0
# Illinois                 80.0
# Indiana                   6.0
# Iowa                     11.0
# Kansas                   12.0
# Kentucky                 19.0
# Louisiana                 3.0
# Maine                     7.0
# Maryland                  2.0
# Massachusetts            12.0
# Michigan                 40.0
# Minnesota                14.0
# Mississippi               1.0
# Missouri                 42.0
# Montana                  12.0
# Nebraska                  2.0
# Nevada                    0.0
# New Hampshire             3.0
# New Jersey               12.0
# ...

# %% [markdown]
# States with the Largest Increase
# State	Increase in Sightings
# Florida
# Illinois
# Michigan
# Missouri
# Ohio
# Texas
# Washington

# %%
# reset the index to make it easier to find the HBFS States
bf_increase1 = bf_increase.reset_index()
bf_increase1
# Out:
#                    State      0
# 0                Alabama   23.0
# 1                 Alaska    0.0
# 2                Arizona   12.0
# 3               Arkansas   19.0
# 4             California   19.0
# 5               Colorado   16.0
# 6            Connecticut    9.0
# 7               Delaware    1.0
# 8   District of Columbia    0.0
# 9                Florida   70.0
# 10               Georgia   22.0
# 11                Hawaii    0.0
# 12                 Idaho   24.0
# 13              Illinois   80.0
# 14               Indiana    6.0
# 15                  Iowa   11.0
# 16                Kansas   12.0
# 17              Kentucky   19.0
# 18             Louisiana    3.0
# 19                 Maine    7.0
# 20              Maryland    2.0
# 21         Massachusetts   12.0
# 22              Michigan   40.0
# 23             Minnesota   14.0
# 24           Mississippi    1.0
# 25              Missouri   42.0
# 26               Montana   12.0
# 27              Nebraska    2.0
# ...

# %%
# Create df of HBFS States
high_bfs = bf_final_state.iloc[[9,13,22,25,35,43,47], :]
high_bfs
# Out:
#               2020 Pop  Percent Change 2010 to 2020 Census    2010 Pop  \
# State
# Florida     21,538,187                                14.6  18,801,310
# Illinois    12,812,508                                -0.1  12,830,632
# Michigan    10,077,331                                 2.0   9,883,640
# Missouri     6,154,913                                 2.8   5,988,927
# Ohio        11,799,448                                 2.3  11,536,504
# Texas       29,145,505                                15.9  25,145,561
# Washington   7,705,281                                14.6   6,724,540
#
#             Percent Change 2000 - Census 2010    2000 Pop   # Missing  \
# State
# Florida                                  17.6  15,982,378        1252
# Illinois                                  3.3  12,419,293         317
# Michigan                                 -0.6   9,938,444         556
# Missouri                                  7.0   5,595,211         316
# ...

# %%
#send HBFS info to csv
high_bfs.to_csv('HBFS Data.csv')

# %% [markdown]
# Find the state rankings for sightings, population, population growth, missing people, alcohol, IUD, SDU

# %%
#Find 2001 to 2010 sighting rankings, set variable for total sightings
sightings_10_total = sightings_00s_state["title"].sum()
sightings_10_total
# Out:
# 1518

# %%
hbfs_2010_sightings = high_bfs["Unnamed: 0_x"]

hbfs_2010_sightings_rank = hbfs_2010_sightings/sightings_10_total
hbfs_2010_sightings_rank
# Out:
# State
# Florida       0.063900
# Illinois      0.040184
# Michigan      0.034256
# Missouri      0.025033
# Ohio          0.050725
# Texas         0.081686
# Washington    0.128458
# Name: Unnamed: 0_x, dtype: float64

# %%
#Find 2011 to 2020 sighting rankings
sightings_20_total= sightings_10s_state["title"].sum()
sightings_20_total
# Out:
# 2384

# %%
hbfs_2020_sightings = high_bfs["20 Title"]

hbfs_2020_sightings_rank= hbfs_2020_sightings/sightings_20_total

hbfs_2020_sightings_rank
# Out:
# State
# Florida       0.070050
# Illinois      0.059144
# Michigan      0.038591
# Missouri      0.033557
# Ohio          0.059564
# Texas         0.068372
# Washington    0.127097
# Name: 20 Title, dtype: float64

# %%
#find missing persons ranking
#missing persons total
missing_total = missing_df["Total Number of Missing Persons"].sum()
missing_total
# Out:
# 15207

# %%
#All missing ranks
missing_ranked = missing_df.sort_values(by="Total Number of Missing Persons", ascending=False)

missing_ranked.head(20)
# Out:
#              State  Total Number of Missing Persons  \
# 4       California                             2133
# 9          Florida                             1252
# 43           Texas                             1246
# 2          Arizona                              915
# 47      Washington                              643
# 32        New York                              606
# 22        Michigan                              556
# 37          Oregon                              432
# 38    Pennsylvania                              401
# 42       Tennessee                              361
# 35            Ohio                              358
# 33  North Carolina                              327
# 13        Illinois                              317
# 25        Missouri                              316
# 1           Alaska                              309
# 30      New Jersey                              299
# 5         Colorado                              292
# ...

# %%
#All alcohol ranks
alcohol_ranked = subs_df2.sort_values(by="Alcohol Use (18+)", ascending=False)


alcohol_ranked.reset_index()
# Out:
#                    State  Unnamed: 0  Illicit Drug Use (18+)  \
# 0   District of Columbia          13                    0.10
# 1             Washington          52                    0.09
# 2              Minnesota          28                    0.06
# 3                Vermont          50                    0.08
# 4           South Dakota          46                    0.07
# 5           Rhode Island          44                    0.08
# 6                 Oregon          42                    0.09
# 7             New Mexico          36                    0.07
# 8          Massachusetts          26                    0.08
# 9                 Kansas          21                    0.07
# 10               Wyoming          55                    0.07
# 11              Colorado          10                    0.09
# 12                  West           4                    0.07
# 13            California           9                    0.07
# ...

# %%
#All illicit drug use ranks
idu_ranked = subs_df2.sort_values(by="Illicit Drug Use (18+)", ascending=False)


idu_ranked.reset_index()
# Out:
#                    State  Unnamed: 0  Illicit Drug Use (18+)  \
# 0   District of Columbia          13                    0.10
# 1               Colorado          10                    0.09
# 2             Washington          52                    0.09
# 3                 Nevada          33                    0.09
# 4                 Oregon          42                    0.09
# 5                Montana          31                    0.08
# 6               Illinois          18                    0.08
# 7               Oklahoma          41                    0.08
# 8           Rhode Island          44                    0.08
# 9               Michigan          27                    0.08
# 10              Arkansas           8                    0.08
# 11               Arizona           7                    0.08
# 12                Alaska           6                    0.08
# 13         Massachusetts          26                    0.08
# ...

# %%
#All substance use disorder ranks
sud_ranked = subs_df2.sort_values(by="Illicit Drug Use (18+)", ascending=False)


sud_ranked.reset_index()
# Out:
#                    State  Unnamed: 0  Illicit Drug Use (18+)  \
# 0   District of Columbia          13                    0.10
# 1               Colorado          10                    0.09
# 2             Washington          52                    0.09
# 3                 Nevada          33                    0.09
# 4                 Oregon          42                    0.09
# 5                Montana          31                    0.08
# 6               Illinois          18                    0.08
# 7               Oklahoma          41                    0.08
# 8           Rhode Island          44                    0.08
# 9               Michigan          27                    0.08
# 10              Arkansas           8                    0.08
# 11               Arizona           7                    0.08
# 12                Alaska           6                    0.08
# 13         Massachusetts          26                    0.08
# ...
